# %% [markdown]
# <a href="https://colab.research.google.com/github/atamayo2/comp-170-su25-project/blob/main/fixed_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-88611657-b3c0-45c2-a0d0-0ab50ea47550" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88611657-b3c0-45c2-a0d0-0ab50ea47550">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
ls
# Out:
# Birthday.py  friends_database.csv  __pycache__/  sample_data/
# Friend.py    MyFriendsApp.py       README.md

# %%
from datetime import datetime
from Birthday import Birthday
from Person import Friend
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-3255983561.py in <cell line: 0>()
#       1 from datetime import datetime
#       2 from Birthday import Birthday
# ----> 3 from Person import Friend
#
# ModuleNotFoundError: No module named 'Person'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df = pd.read_csv("friends_database.csv")
df.head()
df.tail()
# Out:
#   first_name last_name  birth_month  birth_day          city
# 1        Obi     Iheme            8         20      Evanston
# 2       Aryn     Burke            3         21       Chicago
# 3     Nicole    Tamayo            6         15      Palatine
# 4      Haley    Hudson            9          6     Edgebrook
# 5      Kevin      Loch            9          4  Morton Grove
